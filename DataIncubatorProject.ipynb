# %%
pip install googlefinance.get
# Out:
# Collecting googlefinance.get
#   Downloading https://files.pythonhosted.org/packages/36/b4/b107f896e21f91443871cdd522b646a90b22dd8651defdf947bb8d96d066/googlefinance.get-0.4.9-py2.py3-none-any.whl
# Requirement already satisfied: requests in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from googlefinance.get) (2.21.0)
# Requirement already satisfied: pandas in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from googlefinance.get) (0.24.2)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from pandas->googlefinance.get) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from pandas->googlefinance.get) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from pandas->googlefinance.get) (1.16.2)
# Requirement already satisfied: six>=1.5 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->googlefinance.get) (1.12.0)
# Installing collected packages: googlefinance.get
# Successfully installed googlefinance.get-0.4.9
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -i https://pypi.python.org/pypi googlefinance.get
# Out:
# Looking in indexes: https://pypi.python.org/pypi
# Requirement already satisfied: googlefinance.get in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (0.4.9)
# Requirement already satisfied: requests in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from googlefinance.get) (2.21.0)
# Requirement already satisfied: pandas in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from googlefinance.get) (0.24.2)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from requests->googlefinance.get) (2.8)
# Requirement already satisfied: pytz>=2011k in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from pandas->googlefinance.get) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from pandas->googlefinance.get) (2.8.0)
# Requirement already satisfied: numpy>=1.12.0 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from pandas->googlefinance.get) (1.16.2)
# Requirement already satisfied: six>=1.5 in /home/diyarbozkurt/myprograms/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->googlefinance.get) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googlefinance.get import get_code

# %%
get_code()
# Out:
# We can get the Code Numbers of "NYSE", "NASDAQ" and "KRX(default)"
# Crawling the Kospi & Kosdaq (default) 's codes
#         Code  Code_int         Google      Name
# 0     001250      1250     KRX:001250     GS글로벌
# 1     082740     82740     KRX:082740     HSD엔진
# 2     001390      1390     KRX:001390     KG케미칼
# 3     011070     11070     KRX:011070     LG이노텍
# 4     010060     10060     KRX:010060       OCI
# 5     001740      1740     KRX:001740    SK네트웍스
# 6     096770     96770     KRX:096770   SK이노베이션
# 7     011810     11810     KRX:011810       STX
# 8     024070     24070     KRX:024070    WISCOM
# 9     011420     11420     KRX:011420   갤럭시아에스엠
# 10    267290    267290     KRX:267290    경동도시가스
# 11    012320     12320     KRX:012320    경동인베스트
# 12    010130     10130     KRX:010130      고려아연
# 13    002240      2240     KRX:002240      고려제강
# 14    014530     14530     KRX:014530      극동유화
# 15    013700     13700     KRX:013700     까뮤이앤씨
# 16    003920      3920     KRX:003920      남양유업
# 17    090350     90350     KRX:090350     노루페인트
# 18    004440      4440     KRX:004440    대림씨엔에스
# 19    014160     14160     KRX:014160      대영포장
# 20    003220      3220     KRX:003220      대원제약
# 21    002880      2880     KRX:002880     대유에이텍
# 22    005880      5880     KRX:005880      대한해운
# 23    023450     23450     KRX:023450      동남합성
# 24    000640       640     KRX:000640  동아쏘시오홀딩스
# 25    001520      1520     KRX:001520        동양
# 26    000400       400     KRX:000400    롯데손해보험
# 27    023530     23530     KRX:023530      롯데쇼핑
# 28    071840     71840     KRX:071840    롯데하이마트
# 29    027740     27740     KRX:027740       마니커
# ...      ...       ...            ...       ...
# 2093  032500     32500  KOSDAQ:032500    케이엠더블유
# 2094  027050     27050  KOSDAQ:027050      코리아나
# 2095  183300    183300  KOSDAQ:183300       코미코
# 2096  950160    950160  KOSDAQ:950160    코오롱티슈진
# 2097  015710     15710  KOSDAQ:015710        코콤
# 2098  066310     66310  KOSDAQ:066310     큐에스아이
# 2099  214150    214150  KOSDAQ:214150      클래시스
# 2100  054780     54780  KOSDAQ:054780      키이스트
# 2101  095610     95610  KOSDAQ:095610        테스
# 2102  089030     89030  KOSDAQ:089030       테크윙
# 2103  054450     54450  KOSDAQ:054450      텔레칩스
# 2104  091440     91440  KOSDAQ:091440      텔레필드
# 2105  200230    200230  KOSDAQ:200230    텔콘RF제약
# 2106  215480    215480  KOSDAQ:215480    토박스코리아
# 2107  177830    177830  KOSDAQ:177830      파버나인
# 2108  047310     47310  KOSDAQ:047310     파워로직스
# 2109  094940     94940  KOSDAQ:094940      푸른기술
# 2110  220100    220100  KOSDAQ:220100       퓨쳐켐
# 2111  035200     35200  KOSDAQ:035200     프럼파스트
# 2112  137400    137400  KOSDAQ:137400       피엔티
# 2113  006140      6140  KOSDAQ:006140     피제이전자
# 2114  149980    149980  KOSDAQ:149980      하이로닉
# 2115  126700    126700  KOSDAQ:126700   하이비젼시스템
# 2116  034950     34950  KOSDAQ:034950    한국기업평가
# 2117  281410    281410  KOSDAQ:281410   한국제6호스팩
# 2118  052600     52600  KOSDAQ:052600       한네트
# 2119  092460     92460  KOSDAQ:092460     한라IMS
# 2120  265920    265920  KOSDAQ:265920    한화수성스팩
# 2121  060560     60560  KOSDAQ:060560    홈센타홀딩스
# 2122  115160    115160  KOSDAQ:115160       휴맥스
#
# [2123 rows x 4 columns]

# %%
get_code('NASDAQ')
# Out:
# We can get the Code Numbers of "NYSE", "NASDAQ" and "KRX(default)"
# Crawling the NASDAQ 's codes
#            Code Symbol                                    Name  LastSale  \
# 0     NASDAQ:YI     YI                               111, Inc.    7.5000
# 1    NASDAQ:PIH    PIH  1347 Property Insurance Holdings, Inc.    5.0332
# 2  NASDAQ:PIHPP  PIHPP  1347 Property Insurance Holdings, Inc.   25.5000
#
#       MarketCap    ADR TSO  IPOyear       Sector                    Industry  \
# 0  5.988416e+07  7984555.0   2018.0  Health Care    Medical/Nursing Services
# 1  3.026344e+07        NaN   2014.0      Finance  Property-Casualty Insurers
# 2  1.785000e+07        NaN      NaN      Finance  Property-Casualty Insurers
#
#                          Summary Quote
# 0     https://www.nasdaq.com/symbol/yi
# 1    https://www.nasdaq.com/symbol/pih
# 2  https://www.nasdaq.com/symbol/pihpp

# %%
get_code('NYSE')
# Out:
# We can get the Code Numbers of "NYSE", "NASDAQ" and "KRX(default)"
# Crawling the NYSE 's codes
#         Code Symbol                    Name  LastSale     MarketCap  ADR TSO  \
# 0   NYSE:DDD    DDD  3D Systems Corporation     11.15  1.300952e+09      NaN
# 1   NYSE:MMM    MMM              3M Company    185.22  1.067658e+11      NaN
# 2  NYSE:WBAI   WBAI         500.com Limited     12.23  5.200255e+08      NaN
#
#    IPOyear             Sector                                 Industry  \
# 0      NaN         Technology  Computer Software: Prepackaged Software
# 1      NaN        Health Care               Medical/Dental Instruments
# 2   2013.0  Consumer Services    Services-Misc. Amusement & Recreation
#
#                         Summary Quote
# 0   https://www.nasdaq.com/symbol/ddd
# 1   https://www.nasdaq.com/symbol/mmm
# 2  https://www.nasdaq.com/symbol/wbai
